# %%
# Câu 1
def getnew(ListA):
  while 10 in ListA:
    ListA.remove(10)
  return ListA
ListA = [1,10,20,5,60,30,10,9,10]
List = getnew(ListA)
print(List)
# Out:
# [1, 20, 5, 60, 30, 9]

# %%
#Câu 2
List1 =["A","B","C","D","E","F"]
List2 =[1,2,3,4,5,6]
dictionary = dict(zip(List1,List2))
print(dictionary)
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6}

# %%
#Câu 3
person={
    "name":"Quoc Nam",
    "age":28,
    "Salary":8000,
    "City":"Tuy Hoa"
}
KeyToRemove=["Salary","City"]
for i in KeyToRemove:
  if i in person:
    person.pop(i)
print(person)
# Out:
# {'name': 'Quoc Nam', 'age': 28}

# %%
# Câu 4 
#a
import pandas as pd
data = pd.read_csv("drive/MyDrive/mobile_data.csv",)
print('Hiển thị 5 dòng đầu:')
data.head(5)
# Out:
# Hiển thị 5 dòng đầu:
#    index      company   body-style  ...  horsepower  average-mileage    price
# 0      0  alfa-romero  convertible  ...         111               21  13495.0
# 1      1  alfa-romero  convertible  ...         111               21  16500.0
# 2      2  alfa-romero    hatchback  ...         154               19  16500.0
# 3      3         audi        sedan  ...         102               24  13950.0
# 4      4         audi        sedan  ...         115               18  17450.0
#
# [5 rows x 10 columns]

# %%
#5 dòng cuối
print('Hiển thị 5 dòng cuối:')
data.tail(5)
# Out:
# Hiển thị 5 dòng cuối:
#     index     company body-style  ...  horsepower  average-mileage    price
# 56     81  volkswagen      sedan  ...          85               27   7975.0
# 57     82  volkswagen      sedan  ...          52               37   7995.0
# 58     86  volkswagen      sedan  ...         100               26   9995.0
# 59     87       volvo      sedan  ...         114               23  12940.0
# 60     88       volvo      wagon  ...         114               23  13415.0
#
# [5 rows x 10 columns]

# %%
#b
import pandas as pd
data = pd.read_csv("drive/MyDrive/mobile_data.csv",na_values=",")
na_values={'price':['?','n.a'],
           'stroke':['?','n.a'],
           'horsepower':['?','n.a'],
           'peak-rpm':['?','n.a'],
           'average-mileage':['?','n.a']}
data
# Out:
#     index      company   body-style  ...  horsepower  average-mileage    price
# 0       0  alfa-romero  convertible  ...         111               21  13495.0
# 1       1  alfa-romero  convertible  ...         111               21  16500.0
# 2       2  alfa-romero    hatchback  ...         154               19  16500.0
# 3       3         audi        sedan  ...         102               24  13950.0
# 4       4         audi        sedan  ...         115               18  17450.0
# ..    ...          ...          ...  ...         ...              ...      ...
# 56     81   volkswagen        sedan  ...          85               27   7975.0
# 57     82   volkswagen        sedan  ...          52               37   7995.0
# 58     86   volkswagen        sedan  ...         100               26   9995.0
# 59     87        volvo        sedan  ...         114               23  12940.0
# 60     88        volvo        wagon  ...         114               23  13415.0
#
# [61 rows x 10 columns]

# %%
#c
import pandas as pd
data = pd.read_csv("drive/MyDrive/mobile_data.csv")
data[data['price'] == data['price'].max()]
# Out:
#     index        company body-style  ...  horsepower  average-mileage    price
# 35     47  mercedes-benz    hardtop  ...         184               14  45400.0
#
# [1 rows x 10 columns]

# %%
#d
import pandas as pd
data = pd.read_csv("drive/MyDrive/mobile_data.csv")
print(data['company'].value_counts('price'))
print(data['company'].value_counts().plot(kind='bar'))
# Out:
# toyota           0.114754
# bmw              0.098361
# mazda            0.081967
# nissan           0.081967
# mercedes-benz    0.065574
# volkswagen       0.065574
# audi             0.065574
# mitsubishi       0.065574
# porsche          0.049180
# isuzu            0.049180
# alfa-romero      0.049180
# honda            0.049180
# chevrolet        0.049180
# jaguar           0.049180
# dodge            0.032787
# volvo            0.032787
# Name: company, dtype: float64
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#e
import pandas as pd
data = pd.read_csv("drive/MyDrive/mobile_data.csv")
data= data.sort_values('price',ascending=True)
data
# Out:
#     index        company body-style  ...  horsepower  average-mileage    price
# 13     16      chevrolet  hatchback  ...          48               47   5151.0
# 27     36          mazda  hatchback  ...          68               30   5195.0
# 48     66         toyota  hatchback  ...          62               35   5348.0
# 36     49     mitsubishi  hatchback  ...          68               37   5389.0
# 28     37          mazda  hatchback  ...          68               31   6095.0
# ..    ...            ...        ...  ...         ...              ...      ...
# 11     14            bmw      sedan  ...         182               16  41315.0
# 35     47  mercedes-benz    hardtop  ...         184               14  45400.0
# 22     31          isuzu      sedan  ...          70               38      NaN
# 23     32          isuzu      sedan  ...          70               38      NaN
# 47     63        porsche  hatchback  ...         288               17      NaN
#
# [61 rows x 10 columns]
